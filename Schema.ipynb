# %% [markdown]
# # 安装用于使Jupyter支持Schema的插件
#
# 参考了[Github](https://nbviewer.jupyter.org/github/Calysto/calysto_scheme/blob/master/notebooks/Reference%20Guide%20for%20Calysto%20Scheme.ipynb)页面进行安装：

# %%
# !pip install --upgrade calysto-scheme --user
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# ...
#   Stored in directory: C:\Users\henryalps\AppData\Local\pip\Cache\wheels\a3\b1\39\5f39bceec9019d688881ed80887afce52925ca794ec53d75c3
# Successfully built yasi
# ...
#   WARNING: The scripts ipcluster.exe, ipcontroller.exe and ipengine.exe are installed in 'C:\Users\henryalps\AppData\Roaming\Python\Python37\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script yasi.exe is installed in 'C:\Users\henryalps\AppData\Roaming\Python\Python37\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
# !python -m calysto_scheme install --user
# Out:
# [InstallKernelSpec] Installed kernelspec calysto_scheme in C:\Users\henryalps\AppData\Roaming\jupyter\kernels\calysto_scheme

# %% [markdown]
# 安装完成后，选择```File->new notebook->Calysto Schema 3```即可。

# %% [markdown]
# ![image.png](attachment:image.png)
